# %% [markdown]
# # zsh tests avec zsh_jupyter_kernel
#
# ## Install
#
# ```bash
# python -m zsh_jupyter_kernel.install
# ```

# %%
ls | grep .ipynb
# Out:
# bash.ipynb
# install.ipynb
# ship-manual.ipynb
# zsh.ipynb
